# %%
import pandas as pd 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD 
from sklearn.preprocessing import normalize 
from sklearn.metrics.pairwise import linear_kernel
import boto

# %%
from helpers import *

# %%
def add(x, y):
    return x + y

# %%
add = lambda x, y: x + y

# %%
##Loading the Data 

reviews= pd.read_csv('https://data-bootcamp-x399.s3.us-east-2.amazonaws.com/Reviews.csv')
reviews_subset = reviews[:1000]
reviews_sub=pd.DataFrame(reviews_subset)
reviews_sub.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
reviews['ProductId'].value_counts()
# Out:
# B007JFMH8M    913
# B002QWP89S    632
# B002QWP8H0    632
# B002QWHJOU    632
# B0026RQTGE    632
#              ...
# B0006NYDCM      1
# B000IEFVFM      1
# B000V53HCC      1
# B004VEKUKG      1
# B0041KQP40      1
# Name: ProductId, Length: 74258, dtype: int64

# %%
top_item_df=reviews[reviews.ProductId=="B007JFMH8M"]
top_item_df.head()
# Out:
#             Id   ProductId          UserId  \
# 562970  562971  B007JFMH8M  A368Z46FIKHSEZ
# 562971  562972  B007JFMH8M  A1JAPP1CXRG57A
# 562972  562973  B007JFMH8M  A2Z9JNXPIEL2B9
# 562973  562974  B007JFMH8M  A31CYJQO3FL586
# 562974  562975  B007JFMH8M  A2KXQ2EKFF3K2G
#
#                                        ProfileName  HelpfulnessNumerator  \
# 562970          jaimoi "Appreciator of good music"                     0
# 562971  Linda Painchaud-Steinman "PARK EDGE BOOKS"                     0
# 562972                                  carwash169                     0
# 562973                       P. Titus "Knitgirlll"                     0
# 562974                                     Jessica                     0
#
#         HelpfulnessDenominator  Score        Time  \
# 562970                       0      5  1343433600
# 562971                       0      5  1343433600
# 562972                       0      5  1343433600
# 562973                       0      5  1343433600
# 562974                       0      5  1343433600
#
#                                                   Summary  \
# 562970                                         Delicious!
# 562971                              Great Anytime of Day!
# 562972                                         Very good!
# 562973  Quaker Oats Oatmeal Raisin Mom Voxbox Review C...
# 562974      Quick, simple HEALTHY snack for the kiddos!!!
#
#                                                      Text
# 562970  I love these cookies!  Not only are they healt...
# 562971  Quaker Soft Baked Oatmeal Cookies with raisins...
# 562972  I am usually not a huge fan of oatmeal cookies...
# 562973  I participated in a product review that includ...
# 562974  My kids loved these. I was very pleased to giv...

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS
stopwords = set(STOPWORDS)
stopwords.update(["br", "href"])
textt = " ".join(review for review in top_item_df.Text)
wordcloud = WordCloud(stopwords=stopwords).generate(textt)
plt.figure(figsize = (15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud1.png')
plt.show()

# %%
#Analyzing text with TF-IDF

stopwords = ENGLISH_STOP_WORDS.union(['br', 'don', 've',' br', 'BR']) #Adding in these after the 1st round, we learned that some of the words were repeated... 
vect = TfidfVectorizer(stop_words=stopwords, max_df=0.50, min_df=2)
X = vect.fit_transform(top_item_df.Text)

# %%
X_dense = X.todense()
coords = PCA(n_components=2).fit_transform(X_dense)
plt.scatter(coords[:, 0], coords[:, 1], c='m')
plt.show()

# %%
def top_tfidf_feats(row, features, top_n=20):
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats, columns=['features', 'score'])
    return df
def top_feats_in_doc(X, features, row_id, top_n=25):
    row = np.squeeze(X[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

# %%
features = vect.get_feature_names()
top_words = (top_feats_in_doc(X, features, 1, 10))

top_words.head(20)

top_words["Indexes"]= top_words["features"].str.find(" br")

top_words
# Out:
#     features     score  Indexes
# 0        day  0.272043       -1
# 1  following  0.267255       -1
# 2     dinner  0.233554       -1
# 3      glass  0.198261       -1
# 4       need  0.177018       -1
# 5    texture  0.144917       -1
# 6  fashioned  0.133627       -1
# 7    evening  0.133627       -1
# 8         mg  0.133627       -1
# 9        150  0.127906       -1

# %% [markdown]
# ### Clustering with KMeans

# %%
n_clusters = 8
clf = KMeans(n_clusters=n_clusters, max_iter=100, init='k-means++', n_init=1)
labels = clf.fit_predict(X)

# %%
X_dense = X.todense()
pca = PCA(n_components=2).fit(X_dense)
coords = pca.transform(X_dense)

# %%
label_colors = ["#2AB0E9", "#2BAF74", "#D7665E", "#CCCCCC", 
                "#D2CA0D", "#522A64", "#A3DB05", "#FC6514"]
colors = [label_colors[i] for i in labels]

# %%
plt.scatter(coords[:, 0], coords[:, 1], c=colors)
# Plot the cluster centers
centroids = clf.cluster_centers_
centroid_coords = pca.transform(centroids)
plt.scatter(centroid_coords[:, 0], centroid_coords[:, 1], marker='X', s=200, linewidths=2, c='#444d60')
plt.show()

# %%
plot_tfidf_classfeats_h(top_feats_per_cluster(X, labels, features, 0.1, 25))

# %% [markdown]
# ### Finding Related Messages

# %%
vec_train = vect.fit_transform(top_item_df.Text)
# print out the vector of the first email
print(vec_train[0:1])
# Out:
#   (0, 611)	0.46285375454285704
#   (0, 470)	0.44470815060644475
#   (0, 33)	0.506498157000323
#   (0, 280)	0.28702035242981067
#   (0, 467)	0.22397596381038454
#   (0, 1052)	0.21772015933002248
#   (0, 494)	0.31835116526855717
#   (0, 627)	0.22397596381038454

# %%
cosine_sim = linear_kernel(vec_train[0:1], vec_train).flatten()
# print out the cosine similarities
print(cosine_sim)
# Out:
# [1.         0.0620815  0.0501357  0.03436284 0.1523754  0.06298304
#  0.03299176 0.03854392 0.04898009 0.         0.         0.04522633
#  0.         0.         0.06130231 0.0739724  0.13128129 0.07563954
#  0.03025177 0.         0.         0.05234234 0.03331349 0.06754789
#  0.         0.08259246 0.09288428 0.09434003 0.         0.
#  0.03381908 0.01402541 0.02318815 0.         0.         0.
#  0.07143006 0.01097768 0.08561524 0.05749814 0.         0.
#  0.10690578 0.         0.01744613 0.         0.02419215 0.15369903
#  0.01319085 0.08773493 0.         0.09434987 0.03404202 0.
#  0.07753555 0.02462464 0.05210719 0.07973243 0.         0.0386575
#  0.07992887 0.08439253 0.02852317 0.08188537 0.04653961 0.02529793
#  0.04305748 0.         0.04506613 0.07374743 0.03299252 0.03557748
#  0.09401422 0.10649221 0.09350042 0.         0.         0.10142465
#  0.         0.         0.08512329 0.01862354 0.12472815 0.09058585
#  0.08644916 0.04724375 0.09597366 0.07591006 0.0710849  0.07409102
#  0.         0.         0.         0.         0.15574816 0.03739777
#  0.04889873 0.01182058 0.05104247 0.03962518 0.09078064 0.0471286
#  0.09034329 0.         0.0319294  0.0063879  0.12531894 0.
#  0.         0.05132489 0.02670069 0.06949244 0.11903439 0.
#  0.08843498 0.02301069 0.04989241 0.03603272 0.03812481 0.
#  0.         0.02388262 0.         0.03107417 0.         0.07143934
#  0.0778092  0.         0.01939981 0.10880152 0.0923353  0.0319404
#  0.09822612 0.09108454 0.         0.09359471 0.         0.15559835
#  0.03355947 0.03035993 0.03592178 0.05071098 0.         0.
#  0.08961108 0.02085531 0.         0.08331011 0.0944472  0.12422134
#  0.         0.0586773  0.         0.02743819 0.05573434 0.
#  0.17765222 0.         0.         0.         0.03584594 0.02436952
#  0.10816569 0.         0.         0.04986482 0.         0.03890997
#  0.         0.03949846 0.06751855 0.03022211 0.05657158 0.
#  0.09984545 0.32283889 0.13040343 0.         0.02808006 0.03034341
#  0.         0.05543461 0.05012991 0.30374316 0.05582138 0.23195922
#  0.         0.08842052 0.         0.         0.04344161 0.
#  0.01759137 0.         0.         0.11471525 0.01525629 0.10475546
#  0.03729448 0.         0.         0.         0.03211307 0.
#  0.         0.         0.04775636 0.06101476 0.0860039  0.0220114
#  0.10124305 0.         0.06931114 0.         0.11994678 0.03544936
#  0.03590751 0.09446099 0.06821909 0.05611274 0.0446583  0.04384082
#  0.         0.03757903 0.         0.03313355 0.         0.08533213
#  0.05836656 0.07519631 0.         0.02792232 0.07240831 0.05269235
#  0.05518801 0.19168168 0.         0.         0.07458732 0.
#  0.05803789 0.         0.09618094 0.05187831 0.1983137  0.
#  0.20136461 0.03595278 0.         0.07512133 0.11690347 0.04054667
#  0.24134895 0.09058181 0.         0.05377833 0.         0.09441508
#  0.         0.         0.         0.05065377 0.03335263 0.
#  0.12448418 0.         0.04991074 0.12120091 0.         0.05026054
#  0.         0.05314999 0.02943576 0.03768989 0.03937109 0.24311796
#  0.         0.10227851 0.06028209 0.06028209 0.08447367 0.03040654
#  0.         0.         0.03024507 0.10416937 0.         0.12685612
#  0.         0.02838968 0.04489347 0.07951413 0.06934959 0.
#  0.04056742 0.03868984 0.         0.         0.         0.
#  0.         0.         0.         0.04984732 0.         0.06334094
#  0.25986113 0.10648088 0.10384994 0.05352684 0.09064064 0.01602278
#  0.         0.01202904 0.01482126 0.07421286 0.03025159 0.08253407
#  0.01480477 0.05094526 0.         0.02336344 0.         0.
#  0.02344168 0.07380308 0.         0.05152645 0.12295218 0.09706025
#  0.08175893 0.         0.05086568 0.0688318  0.11153303 0.
#  0.05612999 0.         0.06331273 0.03434053 0.         0.04619259
#  0.06633266 0.         0.04083075 0.03608956 0.06689875 0.04566081
#  0.         0.03461671 0.11711902 0.03063667 0.07111418 0.1241655
#  0.        ]

# %%
query = "influenster"

# %%
vec_query = vect.transform([query])

# %%
cosine_sim = linear_kernel(vec_query, vec_train).flatten()

# %%
# Find top 10 most related emails to the query.
related_email_indices = cosine_sim.argsort()[:-10:-1]
# print out the indices of the 10 most related emails.
print(related_email_indices)
# Out:
# [849 869 486 798  58 552 201 426 173]

# %%
# print out the first email 
first_email_index = related_email_indices[0]
# Out:
# 849
